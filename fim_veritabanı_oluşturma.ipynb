# %% [markdown]
# <a href="https://colab.research.google.com/github/betuuulsan/python_odevleri/blob/main/fim_veritaban%C4%B1_olu%C5%9Fturma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
film_veritabani = {
    "Truman Show": {
        "kategoriler": ["Komedi", "Bilim Kurgu"],
        "aktörler": ["Jim Carrey", "Laura Linney"],
        "yönetmen": "Peter Weir",
        "yapım_yılı": 1998
    },
    "Iron Man": {
        "kategoriler": ["Aksiyon", "Bilim Kurgu"],
        "aktörler": ["Robert Downey JR.", "Gwyneth Paltrow"],
        "yönetmen": "Jon Favreau",
        "yapım_yılı": 2008
    },
    "E.T": {
        "kategoriler": "Bilim Kurgu",
        "aktörler": ["Henry Thomas", "Drew Barrymore"],
        "yönetmen": "Steven Spielberg",
        "yapım_yılı": 1987
    },
    "Geleceğe Dönüş": {
        "kategoriler": ["Bilim Kurgu", "Komedi"],
        "aktörler": ["Christopher Lloyd", "Michael J. Fox"],
        "yönetmen": "Robert Zemeckis",
        "yapım_yılı": 1985
    },
    "Yüzüklerin Efendisi: Yüzük Kardeşliği": {
        "kategoriler": ["Bilim Kurgu", "Aksiyon"],
        "aktörler": ["Elijah Wood", "Viggo Mortensen"],
        "yönetmen": "Peter Jackson",
        "yapım_yılı": 2001
    },
    "Matrix": {
        "kategoriler": ["Aksiyon", "Bilim Kurgu"],
        "aktörler": ["Keanu Reeves", "Laurence Fishburne"],
        "yönetmen": "The Wachowskis",
        "yapım_yılı": 1999
    },
    "O": {
        "kategoriler": ["Gizem", "Korku"],
        "aktörler": ["Bill Skarsgard", "Jaeden Martell"],
        "yönetmen": "Andres Muschietti",
        "yapım_yılı": 2017
    },
    "Hachiko: A Dog's Story": {
        "kategoriler": "Drama",
        "aktörler": ["Richard Gere", "Joan Allen"],
        "yönetmen": "Lasse Hallström",
        "yapım_yılı": 2009
    },
    "Bitirim İkili": {
        "kategoriler": ["Aksiyon", "Komedi"],
        "aktörler": ["Jackie Chan", "Chris Tucker"],
        "yönetmen": "Brett Ratner",
        "yapım_yılı": 1998
    },
    "Jumanji": {
        "kategoriler": ["Aksiyon", "Fantastik"],
        "aktörler": ["Robin Williams", "Kirsten Dunst"],
        "yönetmen": "Joe Johnston",
        "yapım_yılı": 1995
    }
}

for film, bilgiler in film_veritabani.items():
    print(film)
    print("Kategoriler:", ", ".join(bilgiler["kategoriler"]))
    print("Aktörler:", ", ".join(bilgiler["aktörler"]))
    print("Yönetmen:", bilgiler["yönetmen"])
    print("Yapım Yılı:", bilgiler["yapım_yılı"])
    print("\n")
# Out:
# Truman Show
# Kategoriler: Komedi, Bilim Kurgu
# Aktörler: Jim Carrey, Laura Linney
# Yönetmen: Peter Weir
# Yapım Yılı: 1998
#
#
# Iron Man
# Kategoriler: Aksiyon, Bilim Kurgu
# Aktörler: Robert Downey JR., Gwyneth Paltrow
# Yönetmen: Jon Favreau
# Yapım Yılı: 2008
#
#
# E.T
# Kategoriler: B, i, l, i, m,  , K, u, r, g, u
# Aktörler: Henry Thomas, Drew Barrymore
# Yönetmen: Steven Spielberg
# Yapım Yılı: 1987
#
#
# Geleceğe Dönüş
# Kategoriler: Bilim Kurgu, Komedi
# Aktörler: Christopher Lloyd, Michael J. Fox
# Yönetmen: Robert Zemeckis
# Yapım Yılı: 1985
#
#
# Yüzüklerin Efendisi: Yüzük Kardeşliği
# Kategoriler: Bilim Kurgu, Aksiyon
# Aktörler: Elijah Wood, Viggo Mortensen
# Yönetmen: Peter Jackson
# Yapım Yılı: 2001
#
#
# Matrix
# Kategoriler: Aksiyon, Bilim Kurgu
# Aktörler: Keanu Reeves, Laurence Fishburne
# Yönetmen: The Wachowskis
# Yapım Yılı: 1999
#
#
# O
# Kategoriler: Gizem, Korku
# Aktörler: Bill Skarsgard, Jaeden Martell
# Yönetmen: Andres Muschietti
# Yapım Yılı: 2017
#
# ...
